# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
datasim1 = np.loadtxt("sim1.txt")
[t, lp, lp_a, lp_b, ld, ld_a, ld_b] = datasim1.T

# %%
plt.plot(t, ld_a, color = 'r', linestyle = '--', label = )
plt.plot(t, ld_b, color = 'c', linestyle = '-.', label)
plt.plot(t, lp_a, color = 'r')
plt.plot(t, lp_b, color = 'g')
plt.axvspan(600, 1200, alpha=0.2, color='grey')
plt.xlabel('Time[s]')
plt.ylabel('Ledger Length[blks]')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
data = np.loadtxt("sim3.txt")
[t, lp, lda, l_awake, l_asleep] = data.T
#Sim3
plt.plot(t, lda, color = 'r')
plt.plot(t, lp, color = 'b')
plt.xlabel('Time[s]')
plt.ylabel('Ledger Length[blks]')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
tshld = 67
min_awake = min(l_awake)
max_awake = max(l_awake)

plt.plot(t, l_awake)
plt.plot(t, [tshld] * len(t))
plt.plot(t, [min_awake] * len(t))
plt.plot(t, [max_awake] * len(t))
plt.ylabel('Awake honest')
plt.show()

# %%
#sim4
datasim1 = np.loadtxt("sim4.txt")
[t, lp, lp_1, lp_2, lda, lda_1, lda_2, l_awake, lasleep] = datasim1.T
# plt.plot(t, ld_a, color = 'r', linestyle = '--', label = )
# plt.plot(t, ld_b, color = 'c', linestyle = '-.', label)
# plt.plot(t, lp_a, color = 'r')
# plt.plot(t, lp_b, color = 'g')
# plt.axvspan(600, 1200, alpha=0.2, color='grey')
# plt.xlabel('Time[s]')
# plt.ylabel('Ledger Length[blks]')
# plt.legend()
# plt.show()
# Out:
#   Input In [57]
#     plt.plot(t, ld_a, color = 'r', linestyle = '--', label = )
#                                                              ^
# SyntaxError: invalid syntax
